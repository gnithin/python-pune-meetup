# %%
import pandas

# %%
pandas.read_csv('isl_wise_train_detail_03082015_v1.csv')
# Out:
#       Train No.       train Name  islno station Code     Station Name  \
# 0       '00851'  BNC SUVIDHA SPL      1         BBS   BHUBANESWAR
# 1       '00851'  BNC SUVIDHA SPL      2         BAM   BRAHMAPUR
# 2       '00851'  BNC SUVIDHA SPL      3         VSKP  VISAKHAPATNAM
# 3       '00851'  BNC SUVIDHA SPL      4         BZA   VIJAYAWADA JN
# 4       '00851'  BNC SUVIDHA SPL      5         RU    RENIGUNTA JN
# 5       '00851'  BNC SUVIDHA SPL      6         JTJ   JOLARPETTAI
# 6       '00851'  BNC SUVIDHA SPL      7         BNC   BANGALORE CANT
# 7       '00852'  BNC BBS SUVIDHA      1         BNC   BANGALORE CANT
# 8       '00852'  BNC BBS SUVIDHA      2         JTJ   JOLARPETTAI
# 9       '00852'  BNC BBS SUVIDHA      3         RU    RENIGUNTA JN
# 10      '00852'  BNC BBS SUVIDHA      4         BZA   VIJAYAWADA JN
# 11      '00852'  BNC BBS SUVIDHA      5         VSKP  VISAKHAPATNAM
# 12      '00852'  BNC BBS SUVIDHA      6         BAM   BRAHMAPUR
# ...

# %%
trains = pandas.read_csv('isl_wise_train_detail_03082015_v1.csv')

# %%
trains.columns
# Out:
# Index([u'Train No.', u'train Name', u'islno', u'station Code', u'Station Name',
#        u'Arrival time', u'Departure time', u'Distance', u'Source Station Code',
#        u'source Station Name', u'Destination station Code',
#        u'Destination Station Name'],
#       dtype='object')

# %%
trains['train Name']
# Out:
# 0        BNC SUVIDHA SPL
# 1        BNC SUVIDHA SPL
# 2        BNC SUVIDHA SPL
# 3        BNC SUVIDHA SPL
# 4        BNC SUVIDHA SPL
# 5        BNC SUVIDHA SPL
# 6        BNC SUVIDHA SPL
# 7        BNC BBS SUVIDHA
# 8        BNC BBS SUVIDHA
# 9        BNC BBS SUVIDHA
# 10       BNC BBS SUVIDHA
# 11       BNC BBS SUVIDHA
# 12       BNC BBS SUVIDHA
# 13       BNC BBS SUVIDHA
# 14       DR BSL T F SPL
# 15       DR BSL T F SPL
# 16       DR BSL T F SPL
# 17       DR BSL T F SPL
# 18       DR BSL T F SPL
# 19       DR BSL T F SPL
# 20       DR BSL T F SPL
# 21       DR BSL T F SPL
# 22       BSL DR T F SPL
# 23       BSL DR T F SPL
# 24       BSL DR T F SPL
# 25       BSL DR T F SPL
# 26       BSL DR T F SPL
# 27       BSL DR T F SPL
# 28       BSL DR T F SPL
# 29       BSL DR T F SPL
#               ...
# 68976    TRIBENI EXPRESS
# 68977    TRIBENI EXPRESS
# 68978    TRIBENI EXPRESS
# 68979    TRIBENI EXPRESS
# 68980    TRIBENI EXPRESS
# 68981    TRIBENI EXPRESS
# ...

# %%
trains['train Name'].unique
# Out:
# <bound method Series.unique of 0        BNC SUVIDHA SPL
# 1        BNC SUVIDHA SPL
# 2        BNC SUVIDHA SPL
# 3        BNC SUVIDHA SPL
# 4        BNC SUVIDHA SPL
# 5        BNC SUVIDHA SPL
# 6        BNC SUVIDHA SPL
# 7        BNC BBS SUVIDHA
# 8        BNC BBS SUVIDHA
# 9        BNC BBS SUVIDHA
# 10       BNC BBS SUVIDHA
# 11       BNC BBS SUVIDHA
# 12       BNC BBS SUVIDHA
# 13       BNC BBS SUVIDHA
# 14       DR BSL T F SPL
# 15       DR BSL T F SPL
# 16       DR BSL T F SPL
# 17       DR BSL T F SPL
# 18       DR BSL T F SPL
# 19       DR BSL T F SPL
# 20       DR BSL T F SPL
# 21       DR BSL T F SPL
# 22       BSL DR T F SPL
# 23       BSL DR T F SPL
# 24       BSL DR T F SPL
# 25       BSL DR T F SPL
# 26       BSL DR T F SPL
# 27       BSL DR T F SPL
# 28       BSL DR T F SPL
# 29       BSL DR T F SPL
#               ...
# 68976    TRIBENI EXPRESS
# 68977    TRIBENI EXPRESS
# 68978    TRIBENI EXPRESS
# 68979    TRIBENI EXPRESS
# 68980    TRIBENI EXPRESS
# ...

# %%
trains['train Name'].unique()
# Out:
# array(['BNC SUVIDHA SPL', 'BNC BBS SUVIDHA', 'DR BSL T F SPL ', ...,
#        'SINA   BAHL    ', 'GRD DNR LINK   ', 'DNR GRD LINK EX'], dtype=object)

# %%
unique_trains = trains['train Name'].unique()

# %%
unique_trains.length
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-57bf5fac70bf> in <module>()
# ----> 1 unique_trains.length
#
# AttributeError: 'numpy.ndarray' object has no attribute 'length'

# %%
len(unique_trains)
# Out:
# 2187

# %%
trains
# Out:
#       Train No.       train Name  islno station Code     Station Name  \
# 0       '00851'  BNC SUVIDHA SPL      1         BBS   BHUBANESWAR
# 1       '00851'  BNC SUVIDHA SPL      2         BAM   BRAHMAPUR
# 2       '00851'  BNC SUVIDHA SPL      3         VSKP  VISAKHAPATNAM
# 3       '00851'  BNC SUVIDHA SPL      4         BZA   VIJAYAWADA JN
# 4       '00851'  BNC SUVIDHA SPL      5         RU    RENIGUNTA JN
# 5       '00851'  BNC SUVIDHA SPL      6         JTJ   JOLARPETTAI
# 6       '00851'  BNC SUVIDHA SPL      7         BNC   BANGALORE CANT
# 7       '00852'  BNC BBS SUVIDHA      1         BNC   BANGALORE CANT
# 8       '00852'  BNC BBS SUVIDHA      2         JTJ   JOLARPETTAI
# 9       '00852'  BNC BBS SUVIDHA      3         RU    RENIGUNTA JN
# 10      '00852'  BNC BBS SUVIDHA      4         BZA   VIJAYAWADA JN
# 11      '00852'  BNC BBS SUVIDHA      5         VSKP  VISAKHAPATNAM
# 12      '00852'  BNC BBS SUVIDHA      6         BAM   BRAHMAPUR
# ...

# %%
trains[trains['69005']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-97cfd06a7a36> in <module>()
# ----> 1 trains[trains['69005']]
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1348         res = cache.get(item)
# ...

# %%
trains[trains['Train No.'] == '69005']
# Out:
# Empty DataFrame
# Columns: [Train No., train Name, islno, station Code, Station Name, Arrival time, Departure time, Distance, Source Station Code, source Station Name, Destination station Code, Destination Station Name]
# Index: []

# %%
type(trains)
# Out:
# pandas.core.frame.DataFrame

# %%
pandas.core.frame.DataFrame??

# %%
dir(pandas.core.frame.DataFrame)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__idiv__',
#  '__imul__',
#  '__init__',
#  '__invert__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdiv__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
# ...

# %%
trains['Train No.'] == '69005'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 68976    False
# 68977    False
# 68978    False
# 68979    False
# 68980    False
# 68981    False
# 68982    False
# 68983    False
# 68984    False
# 68985    False
# 68986    False
# 68987    False
# 68988    False
# 68989    False
# 68990    False
# 68991    False
# 68992    False
# 68993    False
# 68994    False
# 68995    False
# 68996    False
# 68997    False
# 68998    False
# 68999    False
# 69000    False
# 69001    False
# 69002    False
# ...

# %%
trains
# Out:
#       Train No.       train Name  islno station Code     Station Name  \
# 0       '00851'  BNC SUVIDHA SPL      1         BBS   BHUBANESWAR
# 1       '00851'  BNC SUVIDHA SPL      2         BAM   BRAHMAPUR
# 2       '00851'  BNC SUVIDHA SPL      3         VSKP  VISAKHAPATNAM
# 3       '00851'  BNC SUVIDHA SPL      4         BZA   VIJAYAWADA JN
# 4       '00851'  BNC SUVIDHA SPL      5         RU    RENIGUNTA JN
# 5       '00851'  BNC SUVIDHA SPL      6         JTJ   JOLARPETTAI
# 6       '00851'  BNC SUVIDHA SPL      7         BNC   BANGALORE CANT
# 7       '00852'  BNC BBS SUVIDHA      1         BNC   BANGALORE CANT
# 8       '00852'  BNC BBS SUVIDHA      2         JTJ   JOLARPETTAI
# 9       '00852'  BNC BBS SUVIDHA      3         RU    RENIGUNTA JN
# 10      '00852'  BNC BBS SUVIDHA      4         BZA   VIJAYAWADA JN
# 11      '00852'  BNC BBS SUVIDHA      5         VSKP  VISAKHAPATNAM
# 12      '00852'  BNC BBS SUVIDHA      6         BAM   BRAHMAPUR
# ...

# %%
    trains[trains['Train No.'] <10]
# Out:
# Empty DataFrame
# Columns: [Train No., train Name, islno, station Code, Station Name, Arrival time, Departure time, Distance, Source Station Code, source Station Name, Destination station Code, Destination Station Name]
# Index: []

# %%
trains[trains['Train No.'] >6000]
# Out:
#       Train No.       train Name  islno station Code     Station Name  \
# 0       '00851'  BNC SUVIDHA SPL      1         BBS   BHUBANESWAR
# 1       '00851'  BNC SUVIDHA SPL      2         BAM   BRAHMAPUR
# 2       '00851'  BNC SUVIDHA SPL      3         VSKP  VISAKHAPATNAM
# 3       '00851'  BNC SUVIDHA SPL      4         BZA   VIJAYAWADA JN
# 4       '00851'  BNC SUVIDHA SPL      5         RU    RENIGUNTA JN
# 5       '00851'  BNC SUVIDHA SPL      6         JTJ   JOLARPETTAI
# 6       '00851'  BNC SUVIDHA SPL      7         BNC   BANGALORE CANT
# 7       '00852'  BNC BBS SUVIDHA      1         BNC   BANGALORE CANT
# 8       '00852'  BNC BBS SUVIDHA      2         JTJ   JOLARPETTAI
# 9       '00852'  BNC BBS SUVIDHA      3         RU    RENIGUNTA JN
# 10      '00852'  BNC BBS SUVIDHA      4         BZA   VIJAYAWADA JN
# 11      '00852'  BNC BBS SUVIDHA      5         VSKP  VISAKHAPATNAM
# 12      '00852'  BNC BBS SUVIDHA      6         BAM   BRAHMAPUR
# ...

# %%
trains['Train No.']
# Out:
# 0        '00851'
# 1        '00851'
# 2        '00851'
# 3        '00851'
# 4        '00851'
# 5        '00851'
# 6        '00851'
# 7        '00852'
# 8        '00852'
# 9        '00852'
# 10       '00852'
# 11       '00852'
# 12       '00852'
# 13       '00852'
# 14       '01081'
# 15       '01081'
# 16       '01081'
# 17       '01081'
# 18       '01081'
# 19       '01081'
# 20       '01081'
# 21       '01081'
# 22       '01082'
# 23       '01082'
# 24       '01082'
# 25       '01082'
# 26       '01082'
# 27       '01082'
# 28       '01082'
# 29       '01082'
#           ...
# 68976    '84369'
# 68977    '84369'
# 68978    '84369'
# 68979    '84369'
# 68980    '84369'
# 68981    '84369'
# 68982    '84369'
# 68983    '84369'
# 68984    '84369'
# 68985    '84369'
# 68986    '84369'
# 68987    '84369'
# 68988    '84369'
# 68989    '84369'
# 68990    '84369'
# 68991    '84369'
# 68992    '84369'
# 68993    '84369'
# 68994    '84369'
# 68995    '84369'
# 68996    '84369'
# ...

# %%
int(trains['Train No.'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-f68f594bb00a> in <module>()
# ----> 1 int(trains['Train No.'])
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/series.pyc in wrapper(self)
#      76             return converter(self.iloc[0])
#      77         raise TypeError("cannot convert the series to "
# ---> 78                         "{0}".format(str(converter)))
#      79
#      80     return wrapper
#
# TypeError: cannot convert the series to <type 'int'>

# %%
trains['Train No.'] == '84369'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 68976    False
# 68977    False
# 68978    False
# 68979    False
# 68980    False
# 68981    False
# 68982    False
# 68983    False
# 68984    False
# 68985    False
# 68986    False
# 68987    False
# 68988    False
# 68989    False
# 68990    False
# 68991    False
# 68992    False
# 68993    False
# 68994    False
# 68995    False
# 68996    False
# 68997    False
# 68998    False
# 68999    False
# 69000    False
# 69001    False
# 69002    False
# ...

# %%
type(trains['Train No.'] == '84369')
# Out:
# pandas.core.series.Series

# %%
# Out:
# Empty DataFrame
# Columns: [Train No., train Name, islno, station Code, Station Name, Arrival time, Departure time, Distance, Source Station Code, source Station Name, Destination station Code, Destination Station Name]
# Index: []

# %%
# Out:
#   File "<ipython-input-26-51afc5ceae37>", line 1
#     trains[trains['islno'] = 1]
#                            ^
# SyntaxError: invalid syntax

# %%
trains[trains['islno'] == 1]
# Out:
#       Train No.       train Name  islno station Code     Station Name  \
# 0       '00851'  BNC SUVIDHA SPL      1         BBS   BHUBANESWAR
# 7       '00852'  BNC BBS SUVIDHA      1         BNC   BANGALORE CANT
# 14      '01081'  DR BSL T F SPL       1         DR    DADAR
# 22      '01082'  BSL DR T F SPL       1         BSL   BHUSAVAL JN
# 30      '01149'  BSL CSN T F SPL      1         BSL   BHUSAVAL JN
# 34      '01150'  CSN BSL T F SPL      1         CSN   CHALISGAON JN
# 38      '01151'  CSN DHI T F SPL      1         CSN   CHALISGAON JN
# 42      '01152'  DHI CSN T F SPL      1         DHI   DHULE
# 46      '01153'  CSN CSTM T F SP      1         CSN   CHALISGAON JN
# 58      '01154'  CSTM CSN T F SP      1         CSTM  MUMBAI CST
# 70      '01156'  PVR NAVI KMN SP      1         JM    JALAMB JN
# 71      '01156'  PVR NAVI KMN SP      1         PVR   PANDHARPUR
# 95      '01401'  NGP TTKL FARE S      1         SUR   SOLAPUR JN
# ...

# %%
trains.columns
# Out:
# Index([u'Train No.', u'train Name', u'islno', u'station Code', u'Station Name',
#        u'Arrival time', u'Departure time', u'Distance', u'Source Station Code',
#        u'source Station Name', u'Destination station Code',
#        u'Destination Station Name'],
#       dtype='object')

# %%
trains.columns.rename({'Train No.': 'train_no'})
# Out:
# Index([u'Train No.', u'train Name', u'islno', u'station Code', u'Station Name',
#        u'Arrival time', u'Departure time', u'Distance', u'Source Station Code',
#        u'source Station Name', u'Destination station Code',
#        u'Destination Station Name'],
#       dtype='object', name={u'Train No.': u'train_no'})

# %%
trains[trains['train_no'] == '84369']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-e6cff410fd3b> in <module>()
# ----> 1 trains[trains['train_no'] == '84369']
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1348         res = cache.get(item)
# ...

# %%
trains.rename(columns={'Train No.': 'train_no'})
# Out:
#       train_no       train Name  islno station Code     Station Name  \
# 0      '00851'  BNC SUVIDHA SPL      1         BBS   BHUBANESWAR
# 1      '00851'  BNC SUVIDHA SPL      2         BAM   BRAHMAPUR
# 2      '00851'  BNC SUVIDHA SPL      3         VSKP  VISAKHAPATNAM
# 3      '00851'  BNC SUVIDHA SPL      4         BZA   VIJAYAWADA JN
# 4      '00851'  BNC SUVIDHA SPL      5         RU    RENIGUNTA JN
# 5      '00851'  BNC SUVIDHA SPL      6         JTJ   JOLARPETTAI
# 6      '00851'  BNC SUVIDHA SPL      7         BNC   BANGALORE CANT
# 7      '00852'  BNC BBS SUVIDHA      1         BNC   BANGALORE CANT
# 8      '00852'  BNC BBS SUVIDHA      2         JTJ   JOLARPETTAI
# 9      '00852'  BNC BBS SUVIDHA      3         RU    RENIGUNTA JN
# 10     '00852'  BNC BBS SUVIDHA      4         BZA   VIJAYAWADA JN
# 11     '00852'  BNC BBS SUVIDHA      5         VSKP  VISAKHAPATNAM
# 12     '00852'  BNC BBS SUVIDHA      6         BAM   BRAHMAPUR
# ...

# %%
trains[trains['train_no'] == '84369']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-e6cff410fd3b> in <module>()
# ----> 1 trains[trains['train_no'] == '84369']
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1348         res = cache.get(item)
# ...

# %%
cleaned_trains = trains.rename(columns={'Train No.': 'train_no'})

# %%
cleaned_trains[cleaned_trains['train_no'] == '84369']
# Out:
# Empty DataFrame
# Columns: [train_no, train Name, islno, station Code, Station Name, Arrival time, Departure time, Distance, Source Station Code, source Station Name, Destination station Code, Destination Station Name]
# Index: []

# %%
cleaned_trains['train_no'] == '84369'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 68976    False
# 68977    False
# 68978    False
# 68979    False
# 68980    False
# 68981    False
# 68982    False
# 68983    False
# 68984    False
# 68985    False
# 68986    False
# 68987    False
# 68988    False
# 68989    False
# 68990    False
# 68991    False
# 68992    False
# 68993    False
# 68994    False
# 68995    False
# 68996    False
# 68997    False
# 68998    False
# 68999    False
# 69000    False
# 69001    False
# 69002    False
# ...

# %%
trains.head()
# Out:
#   Train No.       train Name  islno station Code     Station Name  \
# 0   '00851'  BNC SUVIDHA SPL      1         BBS   BHUBANESWAR
# 1   '00851'  BNC SUVIDHA SPL      2         BAM   BRAHMAPUR
# 2   '00851'  BNC SUVIDHA SPL      3         VSKP  VISAKHAPATNAM
# 3   '00851'  BNC SUVIDHA SPL      4         BZA   VIJAYAWADA JN
# 4   '00851'  BNC SUVIDHA SPL      5         RU    RENIGUNTA JN
#
#   Arrival time Departure time  Distance Source Station Code  \
# 0   '00:00:00'     '22:50:00'         0                BBS
# 1   '01:10:00'     '01:12:00'       166                BBS
# 2   '05:10:00'     '05:30:00'       443                BBS
# 3   '11:10:00'     '11:20:00'       793                BBS
# 4   '16:42:00'     '16:52:00'      1169                BBS
#
#   source Station Name Destination station Code Destination Station Name
# 0     BHUBANESWAR                         BNC           BANGALORE CANT
# 1     BHUBANESWAR                         BNC           BANGALORE CANT
# ...

# %%
trains[trains['Train No.']=="'00851'"]
# Out:
#   Train No.       train Name  islno station Code     Station Name  \
# 0   '00851'  BNC SUVIDHA SPL      1         BBS   BHUBANESWAR
# 1   '00851'  BNC SUVIDHA SPL      2         BAM   BRAHMAPUR
# 2   '00851'  BNC SUVIDHA SPL      3         VSKP  VISAKHAPATNAM
# 3   '00851'  BNC SUVIDHA SPL      4         BZA   VIJAYAWADA JN
# 4   '00851'  BNC SUVIDHA SPL      5         RU    RENIGUNTA JN
# 5   '00851'  BNC SUVIDHA SPL      6         JTJ   JOLARPETTAI
# 6   '00851'  BNC SUVIDHA SPL      7         BNC   BANGALORE CANT
#
#   Arrival time Departure time  Distance Source Station Code  \
# 0   '00:00:00'     '22:50:00'         0                BBS
# 1   '01:10:00'     '01:12:00'       166                BBS
# 2   '05:10:00'     '05:30:00'       443                BBS
# 3   '11:10:00'     '11:20:00'       793                BBS
# 4   '16:42:00'     '16:52:00'      1169                BBS
# 5   '20:35:00'     '20:37:00'      1367                BBS
# ...

# %%
trains['Train No.'] = trains['Train No.'].str.replace('\'','')

# %%
trains.head()
# Out:
#   Train No.       train Name  islno station Code     Station Name  \
# 0     00851  BNC SUVIDHA SPL      1         BBS   BHUBANESWAR
# 1     00851  BNC SUVIDHA SPL      2         BAM   BRAHMAPUR
# 2     00851  BNC SUVIDHA SPL      3         VSKP  VISAKHAPATNAM
# 3     00851  BNC SUVIDHA SPL      4         BZA   VIJAYAWADA JN
# 4     00851  BNC SUVIDHA SPL      5         RU    RENIGUNTA JN
#
#   Arrival time Departure time  Distance Source Station Code  \
# 0   '00:00:00'     '22:50:00'         0                BBS
# 1   '01:10:00'     '01:12:00'       166                BBS
# 2   '05:10:00'     '05:30:00'       443                BBS
# 3   '11:10:00'     '11:20:00'       793                BBS
# 4   '16:42:00'     '16:52:00'      1169                BBS
#
#   source Station Name Destination station Code Destination Station Name
# 0     BHUBANESWAR                         BNC           BANGALORE CANT
# 1     BHUBANESWAR                         BNC           BANGALORE CANT
# ...

# %%
trains[trains['Train No.']=='00851']
# Out:
#   Train No.       train Name  islno station Code     Station Name  \
# 0     00851  BNC SUVIDHA SPL      1         BBS   BHUBANESWAR
# 1     00851  BNC SUVIDHA SPL      2         BAM   BRAHMAPUR
# 2     00851  BNC SUVIDHA SPL      3         VSKP  VISAKHAPATNAM
# 3     00851  BNC SUVIDHA SPL      4         BZA   VIJAYAWADA JN
# 4     00851  BNC SUVIDHA SPL      5         RU    RENIGUNTA JN
# 5     00851  BNC SUVIDHA SPL      6         JTJ   JOLARPETTAI
# 6     00851  BNC SUVIDHA SPL      7         BNC   BANGALORE CANT
#
#   Arrival time Departure time  Distance Source Station Code  \
# 0   '00:00:00'     '22:50:00'         0                BBS
# 1   '01:10:00'     '01:12:00'       166                BBS
# 2   '05:10:00'     '05:30:00'       443                BBS
# 3   '11:10:00'     '11:20:00'       793                BBS
# 4   '16:42:00'     '16:52:00'      1169                BBS
# 5   '20:35:00'     '20:37:00'      1367                BBS
# ...

# %%
trains[trains['Train No.']=='00851'][-1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-31da346aa544> in <module>()
# ----> 1 trains[trains['Train No.']=='00851'][-1]
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1348         res = cache.get(item)
# ...

# %%
trains[trains['Train No.']=='00851'][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-8310448def90> in <module>()
# ----> 1 trains[trains['Train No.']=='00851'][0]
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1348         res = cache.get(item)
# ...

# %%
x = trains[trains['Train No.']=='00851']

# %%
len(x)
# Out:
# 7

# %%
x[-1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-c30dd0d358dc> in <module>()
# ----> 1 x[-1]
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1348         res = cache.get(item)
#    1349         if res is None:
# ...

# %%
x.__getitem__
# Out:
# <bound method DataFrame.__getitem__ of   Train No.       train Name  islno station Code     Station Name  \
# 0     00851  BNC SUVIDHA SPL      1         BBS   BHUBANESWAR
# 1     00851  BNC SUVIDHA SPL      2         BAM   BRAHMAPUR
# 2     00851  BNC SUVIDHA SPL      3         VSKP  VISAKHAPATNAM
# 3     00851  BNC SUVIDHA SPL      4         BZA   VIJAYAWADA JN
# 4     00851  BNC SUVIDHA SPL      5         RU    RENIGUNTA JN
# 5     00851  BNC SUVIDHA SPL      6         JTJ   JOLARPETTAI
# 6     00851  BNC SUVIDHA SPL      7         BNC   BANGALORE CANT
#
#   Arrival time Departure time  Distance Source Station Code  \
# 0   '00:00:00'     '22:50:00'         0                BBS
# 1   '01:10:00'     '01:12:00'       166                BBS
# 2   '05:10:00'     '05:30:00'       443                BBS
# 3   '11:10:00'     '11:20:00'       793                BBS
# 4   '16:42:00'     '16:52:00'      1169                BBS
# 5   '20:35:00'     '20:37:00'      1367                BBS
# ...

# %%
x.iloc(-1)

# %%
x.iloc[-1]
# Out:
# Train No.                             00851
# train Name                  BNC SUVIDHA SPL
# islno                                     7
# station Code                           BNC
# Station Name                BANGALORE CANT
# Arrival time                     '22:40:00'
# Departure time                   '00:00:00'
# Distance                               1511
# Source Station Code                    BBS
# source Station Name         BHUBANESWAR
# Destination station Code               BNC
# Destination Station Name    BANGALORE CANT
# Name: 6, dtype: object

# %%
trains[trains['Train No.']=='00851'].iloc[-1]['Distance']
# Out:
# 1511

# %%
def train_distance(train_no):
    return trains[trains['Train No.']==train_no].iloc[-1]['Distance']

# %%
train_distance('00851')
# Out:
# 1511

# %%
trains['Train No.'].unique()
# Out:
# array(['00851', '00852', '01081', ..., '83131', '83132', '84369'], dtype=object)

# %%
for train_no in trains['Train No.'].unique():
    print('Train ' + trains[trains['Train No.'] == train_no].iloc[0]['train Name'] + ' travelled ' + train_distance(train_no))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-d3e30b8475a9> in <module>()
#       1 for train_no in trains['Train No.'].unique():
# ----> 2     print('Train ' + trains[trains['Train No.'] == train_no].iloc[0]['train Name'] + ' travelled ' + train_distance(train_no))
#
# TypeError: ufunc 'add' did not contain a loop with signature matching types dtype('S32') dtype('S32') dtype('S32')

# %%
for train_no in trains['Train No.'].unique():
    print('Train ' + trains[trains['Train No.'] == train_no].iloc[0]['train Name'])
# Out:
# Train BNC SUVIDHA SPL
# Train BNC BBS SUVIDHA
# Train DR BSL T F SPL
# Train BSL DR T F SPL
# Train BSL CSN T F SPL
# Train CSN BSL T F SPL
# Train CSN DHI T F SPL
# Train DHI CSN T F SPL
# Train CSN CSTM T F SP
# Train CSTM CSN T F SP
# Train PVR NAVI KMN SP
# Train NGP TTKL FARE S
# Train NGP SUR T F SPL
# Train PAU TTKL FARE S
# Train PAU KOP SPL
# Train PVR TTKL FAREPA
# Train MRJ TKL FARE PA
# Train PUNE JBP SUP SP
# Train JBP PUNE SPECIA
# Train CSTM JBP SPL
# Train JBP LTT SUP SPL
# Train LTT HBJ SUP SPL
# Train HBJ CSTM SUP SP
# Train LTT LKO AC SPL
# Train LKO  LTT AC SPL
# Train BNC KYQ SUVIDHA
# Train KYQ BNC SUVIDHA
# Train KYQ KUMBH SPL
# Train KYQ PUNE SPECIA
# Train GORAKHPUR  SPL
# Train VSG SBC LINK EX
# Train SUVIDHA SPECIAL
# Train VSKP TPTY SF SP
# Train TPTY VSKP SF SP
# Train KJM SPECIAL
# Train KJM VSKP EXP
# Train SUVIDHA SPL
# Train SBG DNR SPECIAL
# Train DNR SBG SPL
# Train BGP DNR SPECIAL
# Train DNR BGP SPL
# Train ANVT SVDK SPL
# Train SVDK ANVT SPL
# ...

# %%
for train_no in trains['Train No.'].unique():
    print(' travelled ' + train_distance(train_no))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-a3068962efb5> in <module>()
#       1 for train_no in trains['Train No.'].unique():
# ----> 2     print(' travelled ' + train_distance(train_no))
#
# TypeError: ufunc 'add' did not contain a loop with signature matching types dtype('S21') dtype('S21') dtype('S21')

# %%
train_distance('00861')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-60-9e22e2601405> in <module>()
# ----> 1 train_distance('00861')
#
# <ipython-input-54-bf47db98f28f> in train_distance(train_no)
#       1 def train_distance(train_no):
# ----> 2     return trains[trains['Train No.']==train_no].iloc[-1]['Distance']
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#    1294             return self._getitem_tuple(key)
#    1295         else:
# -> 1296             return self._getitem_axis(key, axis=0)
#    1297
#    1298     def _getitem_axis(self, key, axis=0):
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/indexing.pyc in _getitem_axis(self, key, axis)
#    1610
#    1611                 # validate the location
# -> 1612                 self._is_valid_integer(key, axis)
#    1613
# ...

# %%
trains.tail(1)
# Out:
#       Train No.       train Name  islno station Code     Station Name  \
# 69005     84369  TRIBENI EXPRESS     39         BE    BAREILLY
#
#       Arrival time Departure time  Distance Source Station Code  \
# 69005   '12:35:00'     '00:00:00'       862                BRWD
#
#       source Station Name Destination station Code Destination Station Name
# 69005     BARWADIH JN                         BE            BAREILLY

# %%
train_distance('84369')
# Out:
# 862

# %%
type(train_distance('84369'))
# Out:
# numpy.int64

# %%
for train_no in trains['Train No.'].unique():
    print('Train ' + trains[trains['Train No.'] == train_no].iloc[0]['train Name'] + ' travelled ' + str(train_distance(train_no)))
# Out:
# Train BNC SUVIDHA SPL travelled 1511
# Train BNC BBS SUVIDHA travelled 1511
# Train DR BSL T F SPL  travelled 436
# Train BSL DR T F SPL  travelled 436
# Train BSL CSN T F SPL travelled 117
# Train CSN BSL T F SPL travelled 117
# Train CSN DHI T F SPL travelled 57
# Train DHI CSN T F SPL travelled 57
# Train CSN CSTM T F SP travelled 328
# Train CSTM CSN T F SP travelled 328
# Train PVR NAVI KMN SP travelled 807
# Train NGP TTKL FARE S travelled 880
# Train NGP SUR T F SPL travelled 880
# Train PAU TTKL FARE S travelled 578
# Train PAU KOP SPL     travelled 578
# Train PVR TTKL FAREPA travelled 137
# Train MRJ TKL FARE PA travelled 137
# Train PUNE JBP SUP SP travelled 1049
# Train JBP PUNE SPECIA travelled 1049
# Train CSTM JBP SPL    travelled 997
# Train JBP LTT SUP SPL travelled 981
# Train LTT HBJ SUP SPL travelled 821
# Train HBJ CSTM SUP SP travelled 837
# Train LTT LKO AC SPL  travelled 1412
# Train LKO  LTT AC SPL travelled 1412
# Train BNC KYQ SUVIDHA travelled 3019
# ...

# %%
def display_all_train_distances():
    for train_no in trains['Train No.'].unique():
        print("Train '" + trains[trains['Train No.'] == train_no].iloc[0]['train Name'] + "' travelled " + str(train_distance(train_no)) + " kms")

# %%
display_all_train_distances()
# Out:
# Train 'BNC SUVIDHA SPL' travelled 1511 kms
# Train 'BNC BBS SUVIDHA' travelled 1511 kms
# Train 'DR BSL T F SPL ' travelled 436 kms
# Train 'BSL DR T F SPL ' travelled 436 kms
# Train 'BSL CSN T F SPL' travelled 117 kms
# Train 'CSN BSL T F SPL' travelled 117 kms
# Train 'CSN DHI T F SPL' travelled 57 kms
# Train 'DHI CSN T F SPL' travelled 57 kms
# Train 'CSN CSTM T F SP' travelled 328 kms
# Train 'CSTM CSN T F SP' travelled 328 kms
# Train 'PVR NAVI KMN SP' travelled 807 kms
# Train 'NGP TTKL FARE S' travelled 880 kms
# Train 'NGP SUR T F SPL' travelled 880 kms
# Train 'PAU TTKL FARE S' travelled 578 kms
# Train 'PAU KOP SPL    ' travelled 578 kms
# Train 'PVR TTKL FAREPA' travelled 137 kms
# Train 'MRJ TKL FARE PA' travelled 137 kms
# Train 'PUNE JBP SUP SP' travelled 1049 kms
# Train 'JBP PUNE SPECIA' travelled 1049 kms
# Train 'CSTM JBP SPL   ' travelled 997 kms
# Train 'JBP LTT SUP SPL' travelled 981 kms
# Train 'LTT HBJ SUP SPL' travelled 821 kms
# ...

# %%
def display_all_train_distances():
    for train_no in trains['Train No.'].unique():
        print("Train '" + trains[trains['Train No.'] == train_no].iloc[0]['train Name'].strip() + "' travelled " + str(train_distance(train_no)) + " kms")

# %%
display_all_train_distances()
# Out:
# Train 'BNC SUVIDHA SPL' travelled 1511 kms
# Train 'BNC BBS SUVIDHA' travelled 1511 kms
# Train 'DR BSL T F SPL' travelled 436 kms
# Train 'BSL DR T F SPL' travelled 436 kms
# Train 'BSL CSN T F SPL' travelled 117 kms
# Train 'CSN BSL T F SPL' travelled 117 kms
# Train 'CSN DHI T F SPL' travelled 57 kms
# Train 'DHI CSN T F SPL' travelled 57 kms
# Train 'CSN CSTM T F SP' travelled 328 kms
# Train 'CSTM CSN T F SP' travelled 328 kms
# Train 'PVR NAVI KMN SP' travelled 807 kms
# Train 'NGP TTKL FARE S' travelled 880 kms
# Train 'NGP SUR T F SPL' travelled 880 kms
# Train 'PAU TTKL FARE S' travelled 578 kms
# Train 'PAU KOP SPL' travelled 578 kms
# Train 'PVR TTKL FAREPA' travelled 137 kms
# Train 'MRJ TKL FARE PA' travelled 137 kms
# Train 'PUNE JBP SUP SP' travelled 1049 kms
# Train 'JBP PUNE SPECIA' travelled 1049 kms
# Train 'CSTM JBP SPL' travelled 997 kms
# Train 'JBP LTT SUP SPL' travelled 981 kms
# Train 'LTT HBJ SUP SPL' travelled 821 kms
# ...

# %%
trains.tail(1)
# Out:
#       Train No.       train Name  islno station Code     Station Name  \
# 69005     84369  TRIBENI EXPRESS     39         BE    BAREILLY
#
#       Arrival time Departure time  Distance Source Station Code  \
# 69005   '12:35:00'     '00:00:00'       862                BRWD
#
#       source Station Name Destination station Code Destination Station Name
# 69005     BARWADIH JN                         BE            BAREILLY

# %%
trains[trains['Train No.'] == '84369']
# Out:
#       Train No.       train Name  islno station Code     Station Name  \
# 68967     84369  TRIBENI EXPRESS      1         BRWD  BARWADIH JN
# 68968     84369  TRIBENI EXPRESS      2         DTO   DALTONGANJ
# 68969     84369  TRIBENI EXPRESS      3         GHD   GARWA ROAD
# 68970     84369  TRIBENI EXPRESS      4         GHQ   GARHWA
# 68971     84369  TRIBENI EXPRESS      5         MQX   MERALGRAM
# 68972     84369  TRIBENI EXPRESS      6         NUQ   NAGAR UNTARI
# 68973     84369  TRIBENI EXPRESS      7         WDM   WYNDHAMGANJ
# 68974     84369  TRIBENI EXPRESS      8         DXN   DUDDHINAGAR
# 68975     84369  TRIBENI EXPRESS      9         RNQ   RENUKUT
# 68976     84369  TRIBENI EXPRESS     10         CPU   CHOPAN
# 68977     84369  TRIBENI EXPRESS     11         AGY   AGORI KHAS
# 68978     84369  TRIBENI EXPRESS     12         CUK   CHURK
# 68979     84369  TRIBENI EXPRESS     13         RBGJ  ROBERTS GANJ
# 68980     84369  TRIBENI EXPRESS     14         LUSA  LUSA
# ...

# %%
trains.columns()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-85d99cb7a622> in <module>()
# ----> 1 trains.columns()
#
# TypeError: 'Index' object is not callable

# %%
trains.column
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-72-6ae1749bdc90> in <module>()
# ----> 1 trains.column
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2670             if name in self._info_axis:
#    2671                 return self[name]
# -> 2672             return object.__getattribute__(self, name)
#    2673
#    2674     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'column'

# %%
trains.columns()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-85d99cb7a622> in <module>()
# ----> 1 trains.columns()
#
# TypeError: 'Index' object is not callable

# %%
trains.columns
# Out:
# Index([u'Train No.', u'train Name', u'islno', u'station Code', u'Station Name',
#        u'Arrival time', u'Departure time', u'Distance', u'Source Station Code',
#        u'source Station Name', u'Destination station Code',
#        u'Destination Station Name'],
#       dtype='object')

# %%
trains.head(1)
# Out:
#   Train No.       train Name  islno station Code     Station Name  \
# 0     00851  BNC SUVIDHA SPL      1         BBS   BHUBANESWAR
#
#   Arrival time Departure time  Distance Source Station Code  \
# 0   '00:00:00'     '22:50:00'         0                BBS
#
#   source Station Name Destination station Code Destination Station Name
# 0     BHUBANESWAR                         BNC           BANGALORE CANT
